# %%
from googletrans import Translator
import pandas as pd
import numpy as np
import re
import csv
import langdetect
from langdetect import detect
from langdetect.lang_detect_exception import LangDetectException
from google.cloud import translate

# %%
#데이터 불러오기
beer_Pilsen= pd.read_csv('/Users/stella/Downloads/beer_필스너.csv', encoding = 'utf-8')

# %%
beer_Pilsen1 = beer_Pilsen[:10]

# %%
# 영어만 추출하기 
text_languages = []
for text in beer_Pilsen['reviews'].dropna():
    try:
        if detect(text) == 'en' :
            text_languages.append({
        'reviews' : text
    })
    except LangDetectException:
        pass

# %%
beer_Pilsen1 = beer_Pilsen[:400]

# %%
df_Pilsen = pd.DataFrame(beer_Pilsen)
print(df_Pilsen)
# Out:
#                                                 reviews
# 0     It is a decent beer , but it is slightly overr...
# 1     biscuits, herbs, lemon grass, butter, golden, ...
# 2     Tall, rocky white head.\r\nAdmittedly very wea...
# 3     First time drink this beer and I think it remi...
# 4     Golden color with a spicy hop aroma.  Taste is...
# 5     01.06.2015 -- pours clear golden colour with a...
# 6     0,5l can. Pours clear straw/golden with white ...
# 7     Aroma: cracker, biscuit malt. grassy and littl...
# 8     About as good as it gets \r\r\nPilsner is very...
# 9     Bottle.  Refined, subdued hoppy aroma and flav...
# 10    Bitter, hoppy pilsener. Malty and very fresh. ...
# 11    Yardstick? Yes, of course... though Heinecken ...
# 12    ,.. it has Compact White head, full bodied Tas...
# 13    Pours a clear golden coloration with a large, ...
# 14    Can, 4.4%. Clear golden, white head. Malt and ...
# 15    Capo di tutti capi of beers. Or lagers at leas...
# ...

# %%
beer_Pilsen1 = df_Pilsen[:4]
beer_Pilsen1
# Out:
#                                              reviews
# 0  It is a decent beer , but it is slightly overr...
# 1  biscuits, herbs, lemon grass, butter, golden, ...
# 2  Tall, rocky white head.\r\nAdmittedly very wea...
# 3  First time drink this beer and I think it remi...

# %%
#텍스트 파일로 바꾸기 
beer_Pilsen.to_csv('/Users/stella/Downloads/beer_필스너.txt', encoding='utf-8',  index = False, header = False)

# %%
file = open('/Users/stella/Downloads/beer_필스너.text', 'r', encoding = 'utf-8')
file_open = file.read()
print(file_open)
file.close()
# Out:
# "It is a decent beer , but it is slightly overrated , it has a bitter taste that remains in the aftertaste."
# "biscuits, herbs, lemon grass, butter, golden, clear, white foam, medium bitterness, light body, lively, good beer"
# "Tall, rocky white head.
# Admittedly very weak nose, maybe some malt and some vanilla.
# Taste more than makes up for it, having the crisp clean drinkability of a standard lager but with just enough nuance and finesse to keep me interested, particularly notes of citrus, cloves, and hay.
# This is the beer to serve with a large plate of unidentified meat."
# First time drink this beer and I think it reminds me more of fosters than any other pilsners ive had before. Not very good
# Golden color with a spicy hop aroma.  Taste is crisp with a moderate spicy hop bitter finish.
# ...

# %%
result = re.sub('[\*|\.|\|\-|\"|\,|\@|\!|\'|\"|\=|\…|\:|\[|\]|\?|\/|\;]', '', file_open)
print(result)
# Out:
# It is a decent beer  but it is slightly overrated  it has a bitter taste that remains in the aftertaste
# biscuits herbs lemon grass butter golden clear white foam medium bitterness light body lively good beer
# Tall rocky white head
# Admittedly very weak nose maybe some malt and some vanilla
# Taste more than makes up for it having the crisp clean drinkability of a standard lager but with just enough nuance and finesse to keep me interested particularly notes of citrus cloves and hay
# This is the beer to serve with a large plate of unidentified meat
# First time drink this beer and I think it reminds me more of fosters than any other pilsners ive had before Not very good

# %%
def papago_translate_text(text):
    client_id = 'u0mNqMsAQlQ_zizpeVT3'
    client_secret = 'R1NPsYx2Yv'
    encText = urllib.parse.quote(text)
    data = "source=en&target=ko&text=" + encText
    url = "https://openapi.naver.com/v1/papago/n2mt"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
    return response_body.decode("utf-8")

# %%
print(result)
# Out:
# It is a decent beer  but it is slightly overrated  it has a bitter taste that remains in the aftertaste
# biscuits herbs lemon grass butter golden clear white foam medium bitterness light body lively good beer
# Tall rocky white head
# Admittedly very weak nose maybe some malt and some vanilla
# Taste more than makes up for it having the crisp clean drinkability of a standard lager but with just enough nuance and finesse to keep me interested particularly notes of citrus cloves and hay
# This is the beer to serve with a large plate of unidentified meat
# First time drink this beer and I think it reminds me more of fosters than any other pilsners ive had before Not very good

# %%
from bs4 import BeautifulSoup as BS

# %%
a = BS(response_body,"lxml")

# %%
# Out:
# ['"translatedText"', '"t"}}}']

# %%
df = []
for text in result: 
    textline = text
    result =  papago_translate_text(textline)
# Out:
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"en","tarLangType":"ko","translatedText":"나는"}}}
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"en","tarLangType":"ko","translatedText":"t"}}}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-203-2602d59a53d4> in <module>
#       2 for text in result:
#       3     textline = text
# ----> 4     result =  papago_translate_text(textline)
#
# <ipython-input-192-1dede83e8f71> in papago_translate_text(text)
#       8     request.add_header("X-Naver-Client-Id",client_id)
#       9     request.add_header("X-Naver-Client-Secret",client_secret)
# ---> 10     response = urllib.request.urlopen(request, data=data.encode("utf-8"))
#      11     rescode = response.getcode()
# ...

# %%
type(d)
# Out:
# str

# %%
# Out:
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"en","tarLangType":"ko","translatedText":"맥주는 괜찮은데 약간 오버가 되어 있는데 뒷맛이 씁쓸하다.\n비스킷 허브 레몬 풀 버터 골든 투명한 흰색 거품 달콤쌉싸름한 가벼운 맥주\n키가 크고 바위투성이의 흰 머리\n인정하건대 아주 약한 코는 아마 맥아와 바닐라\n표준 라거의 바삭바삭한 청량음료로 보충하는 것 이상의 맛과 감귤류 정향과 건초를 특별히 관심을 끌기 위한 충분한 뉘앙스와 재주를 가지고 맛보십시오.\n이것은 신원 미상의 고기의 큰 접시에 담는 맥주다.\n처음으로 이 맥주를 마셨더니, 나는 이것이 나에게 이전에는 별로 좋지 않았던 다른 필로더들 보다 더 많은 재배자들을 생각나게 한다고 생각한다."}}}

# %%
print(d)
# Out:
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"en","tarLangType":"ko","translatedText":"맥주는 괜찮은데 약간 오버가 되어 있는데 뒷맛이 씁쓸하다.\n비스킷 허브 레몬 풀 버터 골든 투명한 흰색 거품 달콤쌉싸름한 가벼운 맥주\n키가 크고 바위투성이의 흰 머리\n인정하건대 아주 약한 코는 아마 맥아와 바닐라\n표준 라거의 바삭바삭한 청량음료로 보충하는 것 이상의 맛과 감귤류 정향과 건초를 특별히 관심을 끌기 위한 충분한 뉘앙스와 재주를 가지고 맛보십시오.\n이것은 신원 미상의 고기의 큰 접시에 담는 맥주다.\n처음으로 이 맥주를 마셨더니, 나는 이것이 나에게 이전에는 별로 좋지 않았던 다른 필로더들 보다 더 많은 재배자들을 생각나게 한다고 생각한다."}}}

# %%
dataframe = pd.DataFrame(df,columns=['reviews'])
dataframe.to_csv('/Users/stella/Downloads/필스너.csv', index=False)

# %%
# Out:
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"en","tarLangType":"ko","translatedText":"h"}}}
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"en","tarLangType":"ko","translatedText":"나는"}}}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-48-8af759fd095b> in <module>
#       2 for trans_text in result:
#       3     text = trans_text
# ----> 4     trans_result = papago_translate_text(text)
#       5     df.append(trans_result)
#
# <ipython-input-47-75c4a0c03db8> in papago_translate_text(text)
#       8     request.add_header("X-Naver-Client-Id",client_id)
#       9     request.add_header("X-Naver-Client-Secret",client_secret)
# ---> 10     response = urllib.request.urlopen(request, data=data.encode("utf-8"))
# ...

# %%
d = papago_translate_text(example_text)
# Out:
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"en","tarLangType":"ko","translatedText":"review0은 괜찮은 맥주지만 약간 부풀려진 맛이 있다1bircuits 레몬 풀 버터와 금빛 흰색 폼의 달콤함 가벼운 맥주2Tall Rocky White Headden Academy2Tally 매우 약한 콧물이 맑고 깨끗한 D를 먹는 것에 대해 보충하는 것보다 조금 더 맛이 있다.표준 라거의 링크 능력 그러나 특별히 흥미를 끌 수 있을 만큼 충분한 뉘앙스와 재주를 가지고 있다.이 맥주는 미확인 고기 한 접시와 함께 대접할 수 있는 맥주3처음 이 맥주를 마시는 것으로 나는 그것이 나에게 매우 좋지 않은 4골든 컬러로 전에 가졌던 어떤 다른 pilsner보다 더 많은 재배자들을 상기시켜준다고 생각한다. 홉 아로마 맛은 중간 정도의 매운 홉 쓴 맛으로 바삭바삭한 501062015년 큰 흰 머리에 투명한 황금색을 뿌리고, 레이싱 아로마향 향료 카라멜 맥스는 겉으로 보기에 아주 쓴 과일로 발전하는데, 이는 +06122018은 여전히 좋으나 약간 달콤하고 버터 같다. 많은 체체코 필스너605l은 백발의 아로마 아로마에게 풀꽃 레몬 맛의 향은 이니셜로 해롭고 약간 달지만 사즈 홉에 그라스 홉스 향신료 레몬의 쓴 파이네르7아로마 크래커 비스킷 맥아리와 작고 매콤한 홉 아로피엔스 황금색을  P다.b 투명도와 곧 사라지는 2핑거리의 흰색 머리에서 약간 벗어난음향 비스킷 말티풀 풀과 약간의 꽃향기 쓴 맛이 눈에 띈다8필스너를 얻는 것만큼 좋은 것은 매우 히트하고 그리워하는 것이지만 이것이 벤치마크9보틀 정제된 hoppy lue 향기와 옅은 노란색 lue classure cle clean clean clean clean clean clean clean clean cAndard lager와 매우 흡사한 Lviv
# ...

# %%
# Out:
# None

# %%
#구글 번역 
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/Users/stella/Downloads/My First Project-d86323cb9c64.json"

# %%
def translate_text(text,target='ko'):
    translate_client = translate.Client()
    result = translate_client.translate(
        text, target_language=target)

    #print(u'Text: {}'.format(result['input']))
    print(u'Translation: {}'.format(result['translatedText']))
    #print(u'Detected source language: {}'.format(
        #result['detectedSourceLanguage']))
    
    translate_client = translate.Client()

# %%
example_text = result
translate_text(example_text, target='ko')
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-216-57aafcb277b1> in <module>
#       1 example_text = result
# ----> 2 translate_text(example_text, target='ko')
#
# <ipython-input-215-8cd6614f5c87> in translate_text(text, target)
#       2     translate_client = translate.Client()
#       3     result = translate_client.translate(
# ----> 4         text, target_language=target)
#       5
#       6     #print(u'Text: {}'.format(result['input']))
#
# /anaconda3/lib/python3.6/site-packages/google/cloud/translate_v2/client.py in translate(self, values, target_language, format_, source_language, customization_ids, model)
#     237         }
#     238
# --> 239         response = self._connection.api_request(method="POST", path="", data=data)
#     240
#     241         translations = response.get("data", {}).get("translations", ())
#
# ...

# %%
# 결과 데이터프레임화
beer_df = pd.DataFrame(Translation)
# csv파일로 추출
beer_df.to_csv('필스너데이터.csv', index=False)

# %%
# 빈데이터 프레임 만들기 
df_Pilsen_empty = pd.DataFrame(index=range(0,len(df_Pilsen)), columns=headers)

# %%
def translate_text(trans_text):
    a = translate_text(trans_text,target='ko')
    return pd.Series([a.origin, a.text], headers)

# %%
#데이터 채우기 
for i, row in enumerate(df_Pilsen['reviews'].values):
    df_Pilsen_empty.loc[i] = translate_text(trans_text)
# Out:
# <function __main__.translate_text(text, target='ko')>

# %%
# 빈데이터 프레임 만들기 
df_Pilsen_empty = pd.DataFrame(index=range(0,len(df_Pilsen)), columns=headers)

# %%
translate_text.to_csv('beer_필스너_번역완료.csv', index=False)
